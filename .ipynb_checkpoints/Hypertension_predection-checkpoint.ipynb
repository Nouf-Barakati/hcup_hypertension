# %% [markdown]
# # Predecting hypertension occurance, time frame and/or its complications

# %%
import pandas as pd
import numpy as np
import time
import re
import os
from operator import add

# %%
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 5000)
pd.set_option('display.width', 50000)

# %% [markdown]
# ### 1- Parse row data file that has patient records that include all visits
#
# input: **patient records**: <br>
# >each record has<br>
# patient ID| Race, Female| list of all visits seperated by #<br>
# >>**each visit record  has**: DaysToEvent, age, list of icd9 codes for that visit, year<br>
#
# output: **visit records**: <br>
# >each record has<br>
# patient ID, Race, Female, DaysToEvent, Age,year, list of icd9 codes for that visit

# %%
# Input data 
icd_code = '40' # icd9 codes for hypertension starts with 401-405 
infile = "HCUP_2003_to_2011_Patient_to_Visits_withoutLine40.csv"
outfile = "patient_visits_Dxs_"+icd_code+".csv"

# preparing the path 
start = os.getcwd()
infile_path = os.path.relpath('..//hcup_data//'+infile, start)
outfile_path = os.path.relpath('..//hcup_data//'+outfile, start)

# %%
def PatientHasDx(infile, outfile, icd_code, bunchsize = 1000):
    bunch = []
    counter = 0
    patient_count = 0
    file_length = 0
    tic = time.perf_counter()
    
    with open(infile, "r") as r, open(outfile, "w") as w:
        for line in r:
            
            # each line is a patient record with multiple visits seperated by #
            counter +=1
            data = line.split("|")
            code1, code2 = data[1].split(",")
            dxlist_all = data[2].split("#")
            l = len(dxlist_all)
            
            # listing all disease in all visits and check if specific disease is appeared
            patient_dxs = [item for sublist in [s.split(',')[2:-1]  for s in dxlist_all] for item in sublist]
            dis_len = len(icd_code)
            has_dx = len([s for s in patient_dxs if (s[:2]=='D_') & (icd_code in s[2:2+dis_len])])>0
            
            if not has_dx:
                continue
            
            file_length += l
            patient_count += 1
            
            # Going through each visit to make it a new record 
            for v in range(l):
                
                # extracting the list of icd codes
                dxlist = dxlist_all[v].split(",")
                year = dxlist[-1].replace("\n", "")
                codes = (dxlist[2:-1])
                
                codes_dx = [c[2:] for c in codes if (c[:2]=='D_') & (c[3:].isnumeric())] 
                
                # discart this visit if it doesn't have any diagnosis codes
                if len(codes_dx)==0:
                    file_length -= 1
                    continue
                bunch.append(','.join((data[0],code1,code2,dxlist[0],dxlist[1],year,' '.join(codes))) + '\n')
            
            if counter >= bunchsize :
                w.writelines(bunch)
                bunch = []
                counter = 0
        w.writelines(bunch)
    
    toc = time.perf_counter()
    print(f"Processed {patient_count} patients who has ICD code starts with {icd_code} in  {toc - tic:0.4f} seconds") 
    print("number of total visit records is: ", str(file_length))

# %%
PatientHasDx(infile_path, outfile_path, icd_code, bunchsize = 1000)
# Out:
# Processed 4473729 patients who has ICD code starts with 40 in  347.7967 seconds
# number of total visit records is:  15583880

# %% [markdown]
# ### 2- One Hot Encode the list of icd9 codes into 120 categories
#
# output: **visit records**: <br>
# >each record has<br>
# patient ID, Race, Female, DaysToEvent, Age,year, list of icd9 codes for that visit
#
# output: **visit records**: <br>
# >each record has<br>
# patient ID, Race, Female, DaysToEvent, Age,year, one hot encoding for the icd9 codes
#
#
# ##### 120 categories are:
# **0**: codes start with V :Supplementary Classification Of Factors Influencing Health Status and Contact With Health Services<br>
# **1-118**: second level of diagnoses<br>
# **119**: Unknown codes (not listed in the second level diagnosis codes)<br>

# %%
icd = pd.read_csv("icd_list.csv", header = 0)

# %%
icd
# Out:
#      min  max                                              Label
# 0      1    9                     Intestinal Infectious Diseases
# 1     10   18                                       Tuberculosis
# 2     20   27                        Zoonotic Bacterial Diseases
# 3     30   41                           Other Bacterial Diseases
# 4     42   42                       Human Immunodeficiency Virus
# 5     45   49  Poliomyelitis And Other Non-Arthropod-Borne Vi...
# 6     50   59             Viral Diseases Accompanied By Exanthem
# 7     60   66                     Arthropod-Borne Viral Diseases
# 8     70   79       Other Diseases Due To Viruses And Chlamydiae
# 9     80   88   Rickettsioses And Other Arthropod-Borne Diseases
# 10    90   99               Syphilis And Other Venereal Diseases
# 11   100  104                         Other Spirochetal Diseases
# 12   110  118                                            Mycoses
# 13   120  129                                      Helminthiases
# 14   130  136            Other Infectious And Parasitic Diseases
# 15   137  139  Late Effects Of Infectious And Parasitic Diseases
# 16   140  149  Malignant Neoplasm Of Lip  Oral Cavity And Pha...
# 17   150  159  Malignant Neoplasm Of Digestive Organs And Per...
# 18   160  165  Malignant Neoplasm Of Respiratory And Intratho...
# 19   170  176  Malignant Neoplasm Of Bone  Connective Tissue ...
# 20   179  189         Malignant Neoplasm Of Genitourinary Organs
# 21   190  199  Malignant Neoplasm Of Other And Unspecified Sites
# 22   200  209  Malignant Neoplasm Of Lymphatic And Hematopoie...
# 23   210  229                                   Benign Neoplasms
# 24   230  234                                  Carcinoma In Situ
# 25   235  238                    Neoplasms Of Uncertain Behavior
# 26   239  239                    Neoplasms Of Unspecified Nature
# 27   240  246                         Disorders Of Thyroid Gland
# 28   249  259                 Diseases Of Other Endocrine Glands
# 29   260  269                           Nutritional Deficiencies
# 30   270  279   Other Metabolic Disorders And Immunity Disorders
# 31   280  280                            Iron deficiency anemias
# 32   281  281                           Other deficiency anemias
# 33   282  282                       Hereditary hemolytic anemias
# 34   283  283                         Acquired hemolytic anemias
# 35   284  284  Aplastic anemia and other bone marrow failure ...
# 36   285  285                      Other and unspecified anemias
# 37   286  286                                Coagulation defects
# 38   287  287           Purpura and other hemorrhagic conditions
# 39   288  288                      Diseases of white blood cells
# 40   289  289   Other diseases of blood and blood-forming organs
# 41   290  294                       Organic Psychotic Conditions
# 42   295  299                                    Other Psychoses
# 43   300  316  Neurotic Disorders  Personality Disorders  And...
# 44   317  319                          Intellectual Disabilities
# 45   320  327  Inflammatory Diseases Of The Central Nervous S...
# 46   330  337  Hereditary And Degenerative Diseases Of The Ce...
# 47   338  338                                               Pain
# 48   339  339                           Other Headache Syndromes
# 49   340  349      Other Disorders Of The Central Nervous System
# 50   350  359         Disorders Of The Peripheral Nervous System
# 51   360  379                    Disorders Of The Eye And Adnexa
# 52   380  389            Diseases Of The Ear And Mastoid Process
# 53   390  392                              Acute Rheumatic Fever
# 54   393  398                    Chronic Rheumatic Heart Disease
# 55   401  405                               Hypertensive Disease
# 56   410  414                             Ischemic Heart Disease
# 57   415  417                  Diseases Of Pulmonary Circulation
# 58   420  429                       Other Forms Of Heart Disease
# 59   430  438                            Cerebrovascular Disease
# 60   440  449   Diseases Of Arteries Arterioles  And Capillaries
# 61   451  459  Diseases Of Veins And Lymphatics  And Other Di...
# 62   460  466                       Acute Respiratory Infections
# 63   470  478          Other Diseases Of Upper Respiratory Tract
# 64   480  488                            Pneumonia And Influenza
# 65   490  496  Chronic Obstructive Pulmonary Disease And Alli...
# 66   500  508  Pneumoconioses And Other Lung Diseases Due To ...
# 67   510  519               Other Diseases Of Respiratory System
# 68   520  529  Diseases Of Oral Cavity  Salivary Glands  And ...
# 69   530  539        Diseases Of Esophagus Stomach  And Duodenum
# 70   540  543                                       Appendicitis
# 71   550  553                         Hernia Of Abdominal Cavity
# 72   555  558                 Noninfective Enteritis And Colitis
# 73   560  569        Other Diseases Of Intestines And Peritoneum
# 74   570  579                 Other Diseases Of Digestive System
# 75   580  589       Nephritis  Nephrotic Syndrome  And Nephrosis
# 76   590  599                   Other Diseases Of Urinary System
# 77   600  608                    Diseases Of Male Genital Organs
# 78   610  612                                Disorders Of Breast
# 79   614  616       Inflammatory Disease Of Female Pelvic Organs
# 80   617  629            Other Disorders Of Female Genital Tract
# 81   630  639  Ectopic And Molar Pregnancy And Other Pregnanc...
# 82   640  649          Complications Mainly Related To Pregnancy
# 83   650  659  Normal Delivery  And Other Indications For Car...
# 84   660  669  Complications Occurring Mainly In The Course O...
# 85   670  677                    Complications Of The Puerperium
# 86   678  679             Other Maternal And Fetal Complications
# 87   680  686         Infections Of Skin And Subcutaneous Tissue
# 88   690  698  Other Inflammatory Conditions Of Skin And Subc...
# 89   700  709     Other Diseases Of Skin And Subcutaneous Tissue
# 90   710  719                Arthropathies And Related Disorders
# 91   720  724                                       Dorsopathies
# 92   725  729                     Rheumatism  Excluding The Back
# 93   730  739  Osteopathies  Chondropathies  And Acquired Mus...
# 94   740  740                     cephalus and similar anomalies
# 95   741  741                                       Spina bifida
# 96   742  742       Other congenital anomalies of nervous system
# 97   743  743                        Congenital anomalies of eye
# 98   744  744          Congenital anomalies of ear face and neck
# 99   745  745  Bulbus cordis anomalies and anomalies of cardi...
# 100  746  746                Other congenital anomalies of heart
# 101  747  747   Other congenital anomalies of circulatory system
# 102  748  748         Congenital anomalies of respiratory system
# 103  749  749                         Cleft palate and cleft lip
# 104  750  750  Other congenital anomalies of upper alimentary...
# 105  751  751     Other congenital anomalies of digestive system
# 106  752  752             Congenital anomalies of genital organs
# 107  753  753             Congenital anomalies of urinary system
# 108  754  754     Certain congenital musculoskeletal deformities
# 109  755  755                Other congenital anomalies of limbs
# 110  756  756         Other congenital musculoskeletal anomalies
# 111  757  757             Congenital anomalies of the integument
# 112  758  758                              Chromosomal anomalies
# 113  759  759         Other and unspecified congenital anomalies
# 114  780  789                                           Symptoms
# 115  790  796                      Nonspecific Abnormal Findings
# 116  797  799  Ill-Defined And Unknown Causes Of Morbidity An...
# 117  800  999                               INJURY AND POISONING

# %%
def coding_120(i):
    if i[:1]=='V':
        return 0
    else:
        i = int(i[:3])
        code = np.where(( (i>=icd['min']) & (i<=icd['max'])))[0]
        if len(code)==0:
            return 119
        return code[0]+1

def coding_1K(i):
     if i[:1]=='V': 
        return 0
     else:
        return int(i[:3])
    
def one_hot(l,width):
    code = [0]*width 
    for i in l:
        x = [0]*width 
        x[i] = 1
        code = list( map(add, code, x) )
    return code

# %%
def encoding_visit_dxs(infile, outfile, bunchsize = 1000):
    bunch = []
    counter = 0
    tic = time.perf_counter()
    with open(infile, "r") as r, open(outfile, "w") as w:
        for line in r:
            counter +=1
            data = line.split(",")
            
            ID, Race, Female, DaysToEvent, Age,year = data[0:6]
            
            codes = data[6].replace("\n","").split(" ")

            codes_dx = [c[2:] for c in codes if (c[:2]=='D_') & (c[3:].isnumeric())] 

            dx_hot_code = one_hot([coding_120(j) for j in codes_dx],120)
            
            bunch.append(','.join((ID,Race,Female,DaysToEvent,Age,year,str(dx_hot_code)[1:-1])) + '\n')
            if counter >= bunchsize :
                w.writelines(bunch)
                bunch = []
                counter = 0
        w.writelines(bunch)
    toc = time.perf_counter()
    print(f"Encoding all visits in  {toc - tic:0.4f} seconds")

# %%
infile = "patient_visits_Dxs_"+icd_code+".csv"
outfile = "patient_visits_Dxs_"+icd_code+"encoded_120.csv"

# preparing the path 
start = os.getcwd()
infile_path = os.path.relpath('..//hcup_data//'+infile, start)
outfile_path = os.path.relpath('..//hcup_data//'+outfile, start)

# %%
encoding_visit_dxs(infile_path, outfile_path, bunchsize = 10000)
